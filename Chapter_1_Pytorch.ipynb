# %%
import torch
import pandas

# %%
x = torch.rand(10)

# %%
x.size()
# Out:
# torch.Size([10])

# %% [markdown]
# ### Vector

# %%
variable = torch.FloatTensor([12,10,8]) ## Float tensor is used for 1 D array to tensor1
variable.size()
# Out:
# torch.Size([3])

# %% [markdown]
# ## 3D VEctors

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.array(Image.open('/home/krutika/Desktop/pigeon.png').resize((126,126)))

# %%
img_tensor = torch.from_numpy(img) ## From numpy is used to convert array to torch tensor

# %%
img_tensor.size()
# Out:
# torch.Size([126, 126, 4])

# %%
plt.imshow(img)

# %% [markdown]
# ## Slicing Tensor

# %%
sales = torch.FloatTensor([100,93,23]) # create required tensor

# %%
sales[:1]
# Out:
# tensor([100.])

# %%
plt.imshow(img_tensor[:,:,0].numpy())

# %% [markdown]
# ## Tensor addition

# %%
a = torch.rand(2,2)
print(a)
# Out:
# tensor([[0.0206, 0.3320],
#         [0.7144, 0.2525]])

# %%
b = torch.rand(2,2)

# %%
c= torch.add(a,b)
print(c)
# Out:
# tensor([[0.0631, 0.3963],
#         [1.2327, 0.8953]])

# %%
d = torch.rand(1,1)
print(d)
# Out:
# tensor([[0.2563]])

# %% [markdown]
# ## Creating dataset

# %%
def data():
    train_x = np.asarray([3,4,5,6,7,8,9,10])
    train_y = np.asarray([2,1,2,1,1,1,1,1])

# %%
y= torch.rand(10)
print(y)
# Out:
# tensor([0.3903, 0.7766, 0.3418, 0.7494, 0.4066, 0.6842, 0.6353, 0.4892, 0.7282,
#         0.8938])

# %%
z= torch.rand([10])
w = torch.rand(10)
print(z)
print(w)
# Out:
# tensor([0.3296, 0.9277, 0.1385, 0.0825, 0.8320, 0.2592, 0.1656, 0.0065, 0.2304,
#         0.2575])
# tensor([0.9983, 0.3290, 0.7418, 0.6492, 0.4877, 0.2420, 0.5710, 0.1640, 0.2263,
#         0.0402])
